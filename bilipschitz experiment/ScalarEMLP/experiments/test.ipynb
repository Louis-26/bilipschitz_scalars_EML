# %%
import lightning.pytorch as pl
from experiments.train_regression_scalars import makeTrainerScalars
from scalaremlp.datasets import Inertia, O5Synthetic, ParticleInteraction

ntrain = 3000

trainer_config = {
    "log_dir": "./logs/",
    "lr": 0.001,
    "num_gpus": 1,
    "max_epochs": 1000,
    "min_epochs": 0,
    "early_stopping": False,
    "early_stopping_patience": 3,
    "check_val_every_n_epoch": 1,
    "milestones": [120, 200, 400, 600, 800],
    "gamma": 0.5,
    "n_out_net": 1,
    "n_hidden_mlp": 500,
    "n_layers_mlp": 5,
    "layer_norm_mlp": False,
}

test_mse = makeTrainerScalars(
    dataset=O5Synthetic,
    ndata=ntrain + 2000,
    epoch_samples=4096,
    bs=512,
    trainer_config=trainer_config,
    progress_bar=True,
)
# Out:
# Using cuda, number of gpus is 1.
# ---------------------------------------------------------------------------
# MisconfigurationException                 Traceback (most recent call last)
# Cell In[3], line 24
#       5 ntrain = 3000
#       7 trainer_config = {
#       8     "log_dir": "./logs/",
#       9     "lr": 0.001,
#    (...)
#      21     "layer_norm_mlp": False,
#      22 }
# ---> 24 test_mse = makeTrainerScalars(
#      25     dataset=O5Synthetic,
#      26     ndata=ntrain + 2000,
#      27     epoch_samples=4096,
#      28     bs=512,
#      29     trainer_config=trainer_config,
#      30     progress_bar=True,
#      31 )
#
# File c:\users\ylu174\my_files\johns hopkins university\term 2\en.553.806-capstone experience\scalaremlp\experiments\train_regression_scalars.py:76, in makeTrainerScalars(dataset, ndata, seed, bs, epoch_samples, device, split, trainer_config, permutation, progress_bar)
#      73     train_loader = dataloaders['train']
#      75 # compute the test metrics
# ---> 76 test_metrics = train_pl_model(
#      77     train_loader=train_loader,
#      78     test_loader=dataloaders['test'],
#      79     validation_loader=dataloaders['val'],
#      80     symname=base_dataset.symname,
#      81     n_in_net=base_trans['dim_scalars'],
#      82     n_hidden_mlp=trainer_config['n_hidden_mlp'],
#      83     n_layers_mlp=trainer_config['n_layers_mlp'],
#      84     layer_norm_mlp=trainer_config['layer_norm_mlp'],
#      85     num_gpus=trainer_config['num_gpus'],
#      86     max_epochs=trainer_config['max_epochs'],
#      87     min_epochs=trainer_config['min_epochs'],
#      88     learning_rate=trainer_config['lr'],
#      89     milestones=trainer_config['milestones'],
#      90     gamma=trainer_config['gamma'],
#      91     check_val_every_n_epoch=trainer_config['check_val_every_n_epoch'],
#      92     path_logs=trainer_config['log_dir'],
#      93     permutation=permutation,
#      94     progress_bar=progress_bar
#      95 )
#      96 return test_metrics
#
# File c:\Users\ylu174\my_files\Johns Hopkins University\Term 2\EN.553.806-Capstone Experience\ScalarEMLP\experiments\trainer\trainer_scalars_nn.py:391, in train_pl_model(n_in_net, n_hidden_mlp, n_layers_mlp, layer_norm_mlp, train_loader, test_loader, validation_loader, symname, num_gpus, max_epochs, min_epochs, learning_rate, milestones, gamma, check_val_every_n_epoch, path_logs, permutation, progress_bar)
#     374 checkpoint_callback = ModelCheckpoint(
#     375     monitor='val_MSE',
#     376     dirpath=path_logs,
#    (...)
#     379     mode='min',
#     380 )
#     382 kwargs = {
#     383     'max_epochs': max_epochs,
#     384     'min_epochs': min_epochs,
#    (...)
#     388     'default_root_dir': path_logs
#     389 }
# --> 391 trainer = pl.Trainer(**kwargs,callbacks=[checkpoint_callback])
#     393 trainer.fit(
#     394     model=litmodel,
#     395     train_dataloaders=train_loader,
#     396     val_dataloaders=validation_loader
#     397 )
#     398 test_metrics = trainer.test(dataloaders=test_loader)[0]
#
# File c:\Users\ylu174\programming_language_setting\Anaconda\envs\scalar_mlp\Lib\site-packages\lightning\pytorch\utilities\argparse.py:70, in _defaults_from_env_vars.<locals>.insert_env_defaults(self, *args, **kwargs)
#      67 kwargs = dict(list(env_variables.items()) + list(kwargs.items()))
#      69 # all args were already moved to kwargs
# ---> 70 return fn(self, **kwargs)
#
# File c:\Users\ylu174\programming_language_setting\Anaconda\envs\scalar_mlp\Lib\site-packages\lightning\pytorch\trainer\trainer.py:396, in Trainer.__init__(self, accelerator, strategy, devices, num_nodes, precision, logger, callbacks, fast_dev_run, max_epochs, min_epochs, max_steps, min_steps, max_time, limit_train_batches, limit_val_batches, limit_test_batches, limit_predict_batches, overfit_batches, val_check_interval, check_val_every_n_epoch, num_sanity_val_steps, log_every_n_steps, enable_checkpointing, enable_progress_bar, enable_model_summary, accumulate_grad_batches, gradient_clip_val, gradient_clip_algorithm, deterministic, benchmark, inference_mode, use_distributed_sampler, profiler, detect_anomaly, barebones, plugins, sync_batchnorm, reload_dataloaders_every_n_epochs, default_root_dir)
#     393 # init connectors
#     394 self._data_connector = _DataConnector(self)
# --> 396 self._accelerator_connector = _AcceleratorConnector(
#     397     devices=devices,
#     398     accelerator=accelerator,
#     399     strategy=strategy,
#     400     num_nodes=num_nodes,
#     401     sync_batchnorm=sync_batchnorm,
#     402     benchmark=benchmark,
#     403     use_distributed_sampler=use_distributed_sampler,
#     404     deterministic=deterministic,
#     405     precision=precision,
#     406     plugins=plugins,
#     407 )
#     408 self._logger_connector = _LoggerConnector(self)
#     409 self._callback_connector = _CallbackConnector(self)
#
# File c:\Users\ylu174\programming_language_setting\Anaconda\envs\scalar_mlp\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:144, in _AcceleratorConnector.__init__(self, devices, num_nodes, accelerator, strategy, plugins, precision, sync_batchnorm, benchmark, use_distributed_sampler, deterministic)
#     142     self._accelerator_flag = self._choose_auto_accelerator()
#     143 elif self._accelerator_flag == "gpu":
# --> 144     self._accelerator_flag = self._choose_gpu_accelerator_backend()
#     146 self._check_device_config_and_set_final_flags(devices=devices, num_nodes=num_nodes)
#     147 self._set_parallel_devices_and_init_accelerator()
#
# File c:\Users\ylu174\programming_language_setting\Anaconda\envs\scalar_mlp\Lib\site-packages\lightning\pytorch\trainer\connectors\accelerator_connector.py:354, in _AcceleratorConnector._choose_gpu_accelerator_backend()
#     352 if CUDAAccelerator.is_available():
#     353     return "cuda"
# --> 354 raise MisconfigurationException("No supported gpu backend found!")
#
# MisconfigurationException: No supported gpu backend found!
