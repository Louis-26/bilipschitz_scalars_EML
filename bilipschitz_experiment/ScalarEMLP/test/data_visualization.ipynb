# %% [markdown]
# ## Double pendulum dataset

# %%
import os
import torch
root_dir=os.path.expanduser("~\\datasets\\ODEDynamics\\DoubleSpringPendulum")
file_name=os.path.join(root_dir,"trajectories_5000_5_0.2_30.pz")
zs=torch.load(file_name, weights_only=False)
# zs=torch.load(file_name, weights_only=True)
print(zs[0].shape)

# p1=os.path.join(os.getcwd(), *"datasets/ODEDynamics/DoubleSpringPendulum".split("/"))
# print(p1)
# Out:
# c:\Users\ylu174\my_file\research\bilipschitz_scalars_EML\bilipschitz_experiment\ScalarEMLP\test
# (5, 12)
# c:\Users\ylu174\my_file\research\bilipschitz_scalars_EML\bilipschitz_experiment\ScalarEMLP\test\datasets\ODEDynamics\DoubleSpringPendulum
